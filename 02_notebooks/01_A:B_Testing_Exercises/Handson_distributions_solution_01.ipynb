# %% [markdown]
# # Probability distributions: a quick refresher
#
# <div class="alert alert-warning">
# <h3>Goal of this session:</h3>
#
# The following tasks are aimed to refresh your mind on some of the key statistical distributions that you will encounter in this course. The insight gained from this session will help you understand:
# - the concept of probability distributions
# - how distributions are changed by different parameters
# - how some distributions are related to each other
#
# Your observations here will help you to have an smooth learning experience when you get to Bayesian statistics in the next session.
# </div>
#
# You will use [SciPy statistical function](https://docs.scipy.org/doc/scipy/reference/stats.html) module and work with several probability distributions through the following steps:
#
# - Generating the mean, variance, skewness, and kurtosis of a distribution
# - Drawing sample from a distribution and plotting them
#
# Let's start by importing the necessary libraries.

# %%
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform, beta, bernoulli, norm, t, gamma, expon, binom

# %%
# define some style for the plots
pvars = dict(histtype='step', bins='auto', density=True, linewidth=1.5)

# %% [markdown]
# ## Example: Normal distribution
# > Use `norm` function. Learn more about it [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html#scipy.stats.norm)

# %%
# set the mean and standard deviation
m, s = 0, 1 

# find the theoretical properties
mean, var, skew, kurt = norm.stats(m, s, moments='mvsk')
display(mean, var, skew, kurt)
# Out:
# 0.0
# 1.0
# 0.0
# 0.0

# %%
# drawing 10000 samples from normal(m,s) distribution 
sample = norm.rvs(m, s, size = (10000,1)) 

# plot probability distribution
plt.hist(sample, **pvars)
plt.xlabel('sample values')
plt.title('Normal PDF')
plt.show()

# %% [markdown]
# ## Exercises
#
# Run the following codes by filling in the empty spaces indicated by `< >`. Then answer the questions in each Task.

# %% [markdown]
# ### Students' T-distribution
# > Use `t` function. Learn more about it [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.t.html#scipy.stats.t)

# %%
# set the degrees of freedom (d>0)
d = 3

# find the theoretical properties
mean, var, skew, kurt = t.stats(d, moments='mvsk')
display(mean, var, skew, kurt)
# Out:
# 0.0
# 3.0
# nan
# inf

# %%
# drawing 10000 samples from Students' T-distribution
sample = t.rvs(d, size = (10000,1)) 

# plot probability distribution
plt.hist(sample, **pvars)
plt.xlabel('sample values')
plt.title('Students-T PDF')
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h4>Task 1</h4>
#
# Let's vary the `degrees of freedom` and see how the distribution changes.
# In particular, compare the outcome with the normal distribution.<br>
# </div>

# %% [markdown]
# **Answer**:
#
# By increasing the degrees of freedom, the distribution becomes more similar to the normal distribution. This is because the t-distribution converges to the normal distribution as the degrees of freedom increases.

# %% [markdown]
# ### Uniform distribution
# > Use `uniform` function. Learn more about it [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.uniform.html#scipy.stats.uniform)

# %%
# set the boundaries (-inf < a <= b < inf)
a, b = 0,1

# find the theoretical properties
mean, var, skew, kurt = uniform.stats(a,b, moments='mvsk')
display(mean, var, skew, kurt)
# Out:
# 0.5
# 0.08333333333333333
# 0.0
# -1.2

# %%
# drawing 10000 samples from uniform(a,b) distribution 
sample = uniform.rvs(a,b, size = (10000,1)) 

# plot probability distribution
plt.hist(sample, **pvars)
plt.xlabel('sample values')
plt.title('Uniform PDF')
plt.show()

# %% [markdown]
# ### Beta distribution
# > Use `beta` function. Learn more about it [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.beta.html#scipy.stats.beta)

# %%
# set the parameters (a>0, b>0)
a, b = 1000,1000

# find the theoretical properties
mean, var, skew, kurt = beta.stats(a,b, moments='mvsk')
display(mean, var, skew, kurt)
# Out:
# 0.5
# 0.0001249375312343828
# 0.0
# -0.0029955067398901645

# %%
# drawing 10000 samples from beta(a,b) distribution 
sample = beta.rvs(a,b, size = (10000,1)) 

# plot probability distribution
plt.hist(sample, **pvars)
plt.xlabel('sample values')
plt.title('Beta PDF')
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h4>Task 2</h4>
#
# Let's vary the `a` and `b` parameters and see how the distribution changes:
#
# 1. Try `a=b=1`, and compare the distribution with the standard Uniform distribution.
# 2. Try `a > b`, what do you learn from the distribution?
# 3. Try `a < b`, what do you learn from the distribution?
# 4. Try `a = b`, what do you learn from the distribution?
# <br>
# </div>

# %% [markdown]
# **Answer**:
#
# 1. with a=b=1, the beta distribution becomes standard Uniform distribution i.e. U(0,1)
#
# 2. with a > b, the beta distribution is skewed to the left. The larger the difference between a and b, the more skewed the distribution is.
#
# 3. with a < b, the beta distribution is skewed to the right. The larger the difference between a and b, the more skewed the distribution is.
#
# 4. with a = b, the beta distribution is symmetric

# %% [markdown]
# <div class="alert alert-info">
# <h4>Task 3</h4>
#
# Redo the uniform distribution for `a = 0, b = 1`.  What is the range of values on the x-axis that both Uniform(0,1) and Beta distributions can take?
# <br>
# </div>

# %% [markdown]
# **Answer**:
#
# The range of values on the x-axis that both Uniform(0,1) and Beta distributions can take is [0,1]. This will make them suitable for describing phenomena whose outcomes are in this range.

# %% [markdown]
# ### Exponential distribution
# > Use `expon` function. Learn more about it [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html#scipy.stats.expon)

# %%
# set the scale parameter (s>0)
lamda = 1000
s = 1/lamda

# find the theoretical properties
mean, var, skew, kurt = expon.stats(loc=0, scale=s, moments='mvsk')
display(mean, var, skew, kurt)
# Out:
# 0.001
# 1e-06
# 2.0
# 6.0

# %%
# drawing 10000 samples from Exponential(s) distribution 
sample = expon.rvs(loc=0, scale=s, size = (10000,1)) 

# plot probability distribution
plt.hist(sample, **pvars)
plt.xlabel('sample values')
plt.title('Exponential PDF')
plt.show()

# %% [markdown]
# ### Gamma distribution
# > Use `gamma` function. Learn more about it [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.gamma.html#scipy.stats.gamma)

# %%
# set the shape and scale parameters (a>0, s>0)
a, s = 100, 10

# find the theoretical properties
mean, var, skew, kurt = gamma.stats(a, loc=0, scale=s, moments='mvsk')
display(mean, var, skew, kurt)
# Out:
# 1000.0
# 10000.0
# 0.2
# 0.06

# %%
# drawing 10000 samples from gamma(a,s) distribution 
sample = gamma.rvs(a, loc=0, scale=s, size = (10000,1)) 

# plot probability distribution
plt.hist(sample, **pvars)
plt.xlabel('sample values')
plt.title('Gamma PDF')
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h4>Task 4</h4>
#
# 1. Vary `a` and `s` parameters and see how the Gamma distribution changes.
#
# 2. Try `a=1` in the Gamma distribution, and set `s` to a value of your choice in both Exponential and Gamma distributions. Do both distributions look similar?
# <br>
# </div>

# %% [markdown]
# **Answer**:
#
# 1. both a and s parameters affect the shape of the gamma distribution. In particular, the scale on the x-axis and the skewness of the distribution are affected by the parameters. The scale parameter s characterizes the dispersion within the exponential and gamma distributions. Modifying the scale parameter has an impact on the extent to which the probability distribution stretches out. When you increase the scale, the distribution extends more to the right, while its  height decreases. Conversely, reducing the scale contracts the distribution to the left and elevates its peak.
#
# 2. with a=1, the gamma(1,s) is the same as the exponential(s). In fact, the exponential distribution is a special case of the gamma distribution, where a=1.

# %% [markdown]
# <div class="alert alert-info">
# <h4>Task 5</h4>
#
#
# What is the range of values on the x-axis that both Exponential and Gamma distributions can take?
# <br>
# </div>

# %% [markdown]
# **Answer**:
#
# The range of values on the x-axis that both Exponential and Gamma distributions can take is [0,inf].

# %% [markdown]
# ### Bernoulli distribution
# > Use `bernoulli` function. Learn more about it [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.bernoulli.html#scipy.stats.bernoulli)

# %%
# set the probability of success (0<=p<=1)
p = .5

# find the theoretical properties
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
display(mean, var, skew, kurt)
# Out:
# 0.5
# 0.25
# 0.0
# -2.0

# %%
# drawing 10000 samples from bernoulli(p) distribution 
sample = bernoulli.rvs(p,size = (10000,1))

# plot probability distribution
plt.hist(sample, **pvars)
plt.xlabel('sample values')
plt.title('Bernoulli PMF')
plt.show()

# %% [markdown]
# ### Binomial distribution
# > Use `binom` function. Learn more about it [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.binom.html#scipy.stats.binom)

# %%
# set the number of trials and probability of success (n>0, 0<=p<=1)
n, p = 1000, .5

# find the theoretical properties
mean, var, skew, kurt = binom.stats(n,p, moments='mvsk')
display(mean, var, skew, kurt)
# Out:
# 500.0
# 250.0
# 0.0
# -0.002

# %%
# drawing 10000 samples from Binomial(n,p) distribution 
sample = binom.rvs(n,p,size = (10000,1))

# plot probability distribution
plt.hist(sample, **pvars)
plt.xlabel('sample values')
plt.title('Binomial PMF')
plt.show()

# %% [markdown]
# <div class="alert alert-info">
# <h4>Task 6</h4>
#
# 1. Vary the `n` and `p` parameters and see how the Binomial distribution changes.
#
# 2. Try `n=1` in the Binomial distribution, and set `p` to a value of your choice in both Bernoulli and Binomial distributions. Do both distributions look similar?
# <br>
# </div>

# %% [markdown]
# **Answer**:
#
# 1. both n and p parameters affect the shape of the binomial distribution. In particular, for larger n, the distribution becomes more similar to the normal distribution. The p parameter affects the skewness of the distribution. When p=0.5, the distribution is symmetric. When p<0.5, the distribution is skewed to the right. When p>0.5, the distribution is skewed to the left.
#
# 2. with n=1, the binomial(1,p) is the same as the bernoulli(p). In fact, the bernoulli distribution is a special case of the binomial distribution with n=1.

# %% [markdown]
# <div class="alert alert-info">
# <h4>Task 7</h4>
#
# What is the range of values on the x-axis that both Bernoulli and Binomial distributions can take?
# <br>
# </div>

# %% [markdown]
# **Answer**:
#
# The range of values on the x-axis that Bernoulli distribution can take is {0,1}. The range of values on the x-axis that Binomial distribution can take is {0,1,...,n}.

# %% [markdown]
# <div class="alert alert-info">
# <h4>Bonus Questions</h4>
#
# 1. Write a code that empirically show the sum of 10 idential and independent Bernoulli random variables with `p=0.5` is a Binomial random variable with `n=10` and `p=0.5`.
#
# <br>
# </div>

# %%
# draw 10 realisations from Bernoulli(0.5) distribution with 1000 samples each
n = 10
p = 0.5
sample = np.sum(bernoulli.rvs(p ,size = (1000,n)),1)
print(sample.mean(), sample.var())
# Out:
# 4.955 2.322975

# %%
# calculate the theoretical moments of the binomial distribution and 
# compare with the sample moments from the sum of 10 Bernoulli random variables
mean, var = binom.stats(n,p, moments='mv')
print(mean, var)
# Out:
# 5.0 2.5

# %% [markdown]
# <div class="alert alert-info">
#
# 2. Write a code that returns the $\alpha$ and $\beta$ in the Beta distribution based on a given mean and variance of this distribution.
#
# <br>
# </div>

# %%
# set the mean and variance of the beta distribution 
m, var = 0.5,.1

# define k>0 as below:
k = m*(1-m)/var-1
print(k)

# obtain the alph and beta parameters based on the mean and variance
a = m*k
b = (1-m)*k

print(a,b)
# Out:
# 1.5
# 0.75 0.75

# %%
# let's check if we get the same m, var based on the beta distribution 
mean, var = beta.stats(a,b, moments='mv')
print(mean, var)
# Out:
# 0.5 0.1
